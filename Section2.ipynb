# %% [markdown]
# **SECTION 2 OF THE PROJECT**

# %%
from matplotlib import pyplot as plt
from numpy.linalg import norm
from math import *
import numpy as np
#import matplotlib as mpl
#mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# **TASK 1**

# %%
plt.figure(figsize=(7,5))
def task_1(x):
   return (abs(x-2)-1)**2

x = np.linspace(0, 5, 1000)

plt.plot(x, task_1(x), color='red')
plt.xlabel('Position of the target')
plt.ylabel('Cost Function value')
plt.title('Cost function ')
plt.show()

# %% [markdown]
# The cost function $(|x-2|-1)^2$, has two local minimums, one positioned at $x = 1$ and the other positioned at $x = 3$.
#
# This is due to the fact that, for range $r=1$, the target must be positioned at $a\pm r =  a \pm 1 $.
# Therefore, if $ a = 2 $, then in order to minimize the value of the cost function for a given $x$, the target must be positioned at either $x = 1$ or $x = 3$. (Perguntar se é preciso demonstrar que os minimos serão aqui com derivadas)
#
# Between the values $x = 1$ and $x = 3$ there is a spike at $x = 2$. This is due to the increasing proximity of the target to the anchor (when we are between these two local minimums) while the measured range is still the same. In mathematical terms we have, $|x-2| \rightarrow 0$ while $ r = 1$.
#
# Finally, the further away the target is from these two local minimums, (i.e $x \rightarrow 0$ or $x \rightarrow +\inf$  ), the more the value of the cost function increases.

# %% [markdown]
# **TASK 2**

# %%
x = np.linspace(-30, 30, 100)
y = np.linspace(-30, 30, 100)
X, Y = np.meshgrid(x, y)
#xy = np.mgrid[0:100:0.1, 0:100:0.1].reshape(2,-1).T
#plt.figure(figsize=(7,7))

def task_2(x,y,a1,a2,r):
   return (np.sqrt((x-a1)**2+(y-a2)**2)-r)**2

plt.contour(X,Y, task_2(X,Y,3,0,3),colors='red')
plt.contour(X,Y, task_2(X,Y,-1,0,2),colors = 'blue')
#task_2(X,Y,-1,0,2)+
plt.xlabel('Position of the target')
plt.ylabel('Cost Function value')
plt.title('Cost function ')
plt.axhline(0, color='black', linewidth=.8)
plt.axvline(0, color='black', linewidth=.8)
plt.show()

# %%
xy = np.mgrid[0:100:0.1, 0:100:0.1].reshape(2,-1).T
x = np.linspace(0, 10, 100)
y = np.linspace(0, 10, 100)
X, Y = np.meshgrid(x, y)



def task_2(x,y,a1,a2,r):
   #return (sqrt((x-a1)**2+(x-a2)**2)-r)**2
   return (np.sqrt((x-a1)**2+(y-a2)**2)-r)**2
task_2(X,Y,-1,0,2)
# Out:
# array([[  1.        ,   0.80818284,   0.63677176, ...,  77.40444853,
#          79.19202122,  81.        ],
#        [  0.98984875,   0.79989075,   0.63002818, ...,  77.4127618 ,
#          79.20035201,  81.00834798],
#        [  0.96000408,   0.77547285,   0.61015084, ...,  77.43770213,
#          79.22534486,  81.03339239],
#        ...,
#        [ 61.60489404,  61.77404491,  61.95951426, ..., 158.27398087,
#         160.16574636, 162.07667326],
#        [ 63.19251346,  63.36209891,  63.54804302, ..., 159.99130154,
#         161.88445325, 163.79675802],
#        [ 64.80049752,  64.97050892,  65.15691838, ..., 161.72751446,
#         163.62204727, 165.53572501]])

# %% [markdown]
# **TASK 3**

# %% [markdown]
# **TASK 4**

# %% [markdown]
# **TASK 5**

# %% [markdown]
# **TASK 6**

# %% [markdown]
# **TASK 7**

# %% [markdown]
# **TASK 8**

# %% [markdown]
# **TASK 9**

# %% [markdown]
# **TASK 10**

# %% [markdown]
# **TASK 11**

# %% [markdown]
# **TASK 12**
